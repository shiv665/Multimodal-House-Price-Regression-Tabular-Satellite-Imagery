# %%
import tensorflow as tf
# Out:
# c:\Users\SHIVANSH YADAV\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\SHIVANSH YADAV\anaconda3\python.exe

# %%
tf.__version__
# Out:
# '2.20.0'
